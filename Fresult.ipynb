# %% [markdown]
# #📚 Student Exam Results Dataset

# %%
# !pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8b54851a-d38f-4b80-b52c-cb2b02bc898c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b54851a-d38f-4b80-b52c-cb2b02bc898c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('/content/results.csv')
print(df.head())
# Out:
#    Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0           0     65       10       59      3       71         37    245
# 1           1     94       56        4     67       91         50    362
# 2           2      7       85       76     99       60         25    352
# 3           3     88       46       59     94       52         38    377
# 4           4     39       81       37     38        6         54    255
#
#    Results  Div
# 0        0    3
# 1        1    1
# 2        0    2
# 3        1    1
# 4        1    3

# %%
print(df.shape)
print(df.columns)
print(df.describe)
print(df.dtypes)
print(df.tail())
# Out:
# (1000, 10)
# Index(['Unnamed: 0', 'Hindi', 'English', 'Science', 'Maths', 'History',
#        'Geograpgy', 'Total', 'Results', 'Div'],
#       dtype='object')
# <bound method NDFrame.describe of      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0             0     65       10       59      3       71         37    245
# 1             1     94       56        4     67       91         50    362
# 2             2      7       85       76     99       60         25    352
# 3             3     88       46       59     94       52         38    377
# 4             4     39       81       37     38        6         54    255
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 995         995     55       89       68     58       13         13    296
# 996         996     42       62       25     87       51         68    335
# 997         997      9       83       70     14       11         78    265
# ...

# %%
print("\nBefore Cleaning Data")
print(df.isnull().sum())
# Out:
# Before Cleaning Data
# Unnamed: 0    0
# Hindi         0
# English       0
# Science       0
# Maths         0
# History       0
# Geograpgy     0
# Total         0
# Results       0
# Div           0
# dtype: int64

# %%
print(df.head())
# Out:
#    Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0           0     65       10       59      3       71         37    245
# 1           1     94       56        4     67       91         50    362
# 2           2      7       85       76     99       60         25    352
# 3           3     88       46       59     94       52         38    377
# 4           4     39       81       37     38        6         54    255
#
#    Results  Div
# 0        0    3
# 1        1    1
# 2        0    2
# 3        1    1
# 4        1    3

# %%
df[df['English']>=50]
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 1             1     94       56        4     67       91         50    362
# 2             2      7       85       76     99       60         25    352
# 4             4     39       81       37     38        6         54    255
# 8             8     15       64       14     43       59         59    254
# 9             9     53       85       96     76       83         62    455
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 995         995     55       89       68     58       13         13    296
# 996         996     42       62       25     87       51         68    335
# 997         997      9       83       70     14       11         78    265
# 998         998     23       82       31     42       84         52    314
# 999         999     75       78       68     33       79         91    424
#
#      Results  Div
# 1          1    1
# 2          0    2
# ...

# %%
df[df['English']>=80]
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 2             2      7       85       76     99       60         25    352
# 4             4     39       81       37     38        6         54    255
# 9             9     53       85       96     76       83         62    455
# 17           17     93       86       36     39       26         78    358
# 24           24     83       86       42     14       39         40    304
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 985         985     12       94       50     84       87         16    343
# 992         992     55       94       59     68       82         89    447
# 995         995     55       89       68     58       13         13    296
# 997         997      9       83       70     14       11         78    265
# 998         998     23       82       31     42       84         52    314
#
#      Results  Div
# 2          0    2
# 4          1    3
# ...

# %%
df[df['Total']>=400]
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 9             9     53       85       96     76       83         62    455
# 29           29     93       41       42     98       72         84    430
# 36           36     84       67       78     98       27         72    426
# 58           58     96       53       60     90       14         90    403
# 60           60     50       66       41     99       89         94    439
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 982         982     76       49       53     93       93         44    408
# 983         983     95       65       89     39       56         73    417
# 986         986     94       61       61     91       65         59    431
# 992         992     55       94       59     68       82         89    447
# 999         999     75       78       68     33       79         91    424
#
#      Results  Div
# 9          1    1
# 29         1    1
# ...

# %%
df[(df['Total']>=300) & (df['Results']==1)]
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 1             1     94       56        4     67       91         50    362
# 3             3     88       46       59     94       52         38    377
# 9             9     53       85       96     76       83         62    455
# 15           15     52       55       39     93       58         46    343
# 17           17     93       86       36     39       26         78    358
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 992         992     55       94       59     68       82         89    447
# 993         993     72       30       34     90       71         36    333
# 994         994     94       62       68     84       13         35    356
# 996         996     42       62       25     87       51         68    335
# 999         999     75       78       68     33       79         91    424
#
#      Results  Div
# 1          1    1
# 3          1    1
# ...

# %%
print(df.head())
# Out:
#    Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0           0     65       10       59      3       71         37    245
# 1           1     94       56        4     67       91         50    362
# 2           2      7       85       76     99       60         25    352
# 3           3     88       46       59     94       52         38    377
# 4           4     39       81       37     38        6         54    255
#
#    Results  Div
# 0        0    3
# 1        1    1
# 2        0    2
# 3        1    1
# 4        1    3

# %%
df.sort_values(by='Total',ascending=True)
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 45           45     33       13       30      2        3         22    103
# 217         217      8       25       24     18       28          0    103
# 586         586     32        1       12     22       41          1    109
# 384         384     61       20       18      5        6          6    116
# 328         328     65        4       33      6        3         11    122
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 612         612     76       93       70     85       51         99    474
# 192         192     81       39       99     90       80         89    478
# 681         681     74       88       90     74       69         84    479
# 834         834     96       96       82     87       67         53    481
# 532         532     88       91       97     93       94         42    505
#
#      Results  Div
# 45         0    0
# 217        0    0
# ...

# %%
df.sort_values(by='Total',ascending=False)
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 532         532     88       91       97     93       94         42    505
# 834         834     96       96       82     87       67         53    481
# 681         681     74       88       90     74       69         84    479
# 192         192     81       39       99     90       80         89    478
# 612         612     76       93       70     85       51         99    474
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 328         328     65        4       33      6        3         11    122
# 384         384     61       20       18      5        6          6    116
# 586         586     32        1       12     22       41          1    109
# 217         217      8       25       24     18       28          0    103
# 45           45     33       13       30      2        3         22    103
#
#      Results  Div
# 532        1    1
# 834        1    1
# ...

# %%
df.groupby('Div')['Total'].mean()
df.groupby('Div')['Total'].sum()
df.groupby('Div')['Total'].max()
df.groupby('Div')['Total'].min()
# Out:
# Div
# 0    103
# 1    361
# 2    271
# 3    199
# Name: Total, dtype: int64

# %%
df.groupby('Results')['Total'].mean()
df.groupby('Results')['Total'].sum()
df.groupby('Results')['Total'].max()
df.groupby('Results')['Total'].min()
# Out:
# Results
# 0    103
# 1    214
# Name: Total, dtype: int64

# %% [markdown]
# #feature Engineering

# %%
df['average']=df[["Hindi","English","Science","Maths","History","Geograpgy"]].mean(axis=1)

# %%
df['core_total']=df[["Maths","Science","English"]].sum(axis=1)

# %%
df['noncore_total']=df[["Hindi","History","Geograpgy"]].sum(axis=1)

# %%
df['best_subject']=df[["Hindi","English","Science","Maths","History","Geograpgy"]].idxmax(axis=1)

# %%
df['math_pass']=(df['Maths']>=33).astype(int)

# %%
df['english_pass']=(df['English']>=33).astype(int)

# %%
bins=[0,200,300,400,500]
labels=['poor','average','good','excellent']
df['grade']=pd.cut(df['Total'],bins=bins,labels=labels)

# %%
print(df.head())
# Out:
#    Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0           0     65       10       59      3       71         37    245
# 1           1     94       56        4     67       91         50    362
# 2           2      7       85       76     99       60         25    352
# 3           3     88       46       59     94       52         38    377
# 4           4     39       81       37     38        6         54    255
#
#    Results  Div    average  core_total  noncore_total best_subject  math_pass  \
# 0        0    3  40.833333          72            173      History          0
# 1        1    1  60.333333         127            235        Hindi          1
# 2        0    2  58.666667         260             92        Maths          1
# 3        1    1  62.833333         199            178        Maths          1
# 4        1    3  42.500000         156             99      English          1
#
#    english_pass    grade
# 0             0  average
# ...

# %%
df.groupby('Total')["grade"].max()
# Out:
# Total
# 103         poor
# 109         poor
# 116         poor
# 122         poor
# 123         poor
#          ...
# 474    excellent
# 478    excellent
# 479    excellent
# 481    excellent
# 505          NaN
# Name: grade, Length: 298, dtype: category
# Categories (4, object): ['poor' < 'average' < 'good' < 'excellent']

# %%
df = pd.get_dummies(df, columns=["best_subject", "grade"], drop_first=True)

# %% [markdown]
# #Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn .metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=df[["average","core_total","noncore_total","math_pass","english_pass"]]
y=df['Results']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("Accuracy_Score",accuracy_score(y_test,y_pred))
print("confusion matrix",confusion_matrix(y_test,y_pred))
print("Classification Report:",classification_report(y_test,y_pred))
# Out:
# Accuracy_Score 0.84
# confusion matrix [[125  14]
#  [ 18  43]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89       139
#            1       0.75      0.70      0.73        61
#
#     accuracy                           0.84       200
#    macro avg       0.81      0.80      0.81       200
# weighted avg       0.84      0.84      0.84       200
